# %%
import pandas as pd
import numpy as np

# helpful modules
import fuzzywuzzy
from fuzzywuzzy import process
import charset_normalizer
# Out:
# /home/jeremy/Work/Data Science/Learning/kaggle-ml/venv/lib/python3.12/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
professors = pd.read_csv("../../Data Cleaning/archive (1)/pakistan_intellectual_capital.csv")

np.random.seed(10)

professors.head()
# Out:
#    Unnamed: 0  S#         Teacher Name  \
# 0           2   3      Dr. Abdul Basit
# 1           4   5      Dr. Waheed Noor
# 2           5   6     Dr. Junaid Baber
# 3           6   7  Dr. Maheen Bakhtyar
# 4          24  25          Samina Azim
#
#             University Currently Teaching             Department  \
# 0               University of Balochistan  Computer Science & IT
# 1               University of Balochistan  Computer Science & IT
# 2               University of Balochistan  Computer Science & IT
# 3               University of Balochistan  Computer Science & IT
# 4  Sardar Bahadur Khan Women's University       Computer Science
#
#   Province University Located          Designation Terminal Degree  \
# 0                 Balochistan  Assistant Professor             PhD
# 1                 Balochistan  Assistant Professor             PhD
# 2                 Balochistan  Assistant Professor             PhD
# ...

# %%
professors.columns
# Out:
# Index(['Unnamed: 0', 'S#', 'Teacher Name', 'University Currently Teaching',
#        'Department', 'Province University Located', 'Designation',
#        'Terminal Degree', 'Graduated from', 'Country', 'Year',
#        'Area of Specialization/Research Interests', 'Other Information'],
#       dtype='object')

# %%
# convert to lower case 
professors["Country"] = professors["Country"].str.lower()
# removing trailing whitespaces
professors["Country"] = professors["Country"].str.strip()

# %%
countries = professors["Country"].unique()

countries.sort()
countries
# Out:
# array(['australia', 'austria', 'canada', 'china', 'finland', 'france',
#        'germany', 'greece', 'hongkong', 'ireland', 'italy', 'japan',
#        'macau', 'malaysia', 'mauritius', 'netherland', 'new zealand',
#        'norway', 'pakistan', 'portugal', 'russian federation',
#        'saudi arabia', 'scotland', 'singapore', 'south korea',
#        'southkorea', 'spain', 'sweden', 'thailand', 'turkey', 'uk',
#        'urbana', 'usa', 'usofa'], dtype=object)

# %%
countries_df = pd.DataFrame(countries)
countries_df.shape
# Out:
# (38, 1)

# %%
# function to replace rows in the provided column of the provided dataframe
# that match the provided string above the provided ratio with the provided string
def replace_matches_in_columns(df, column, string_to_match, min_ratio = 47):
    # get a list of strings
    strings = df[column].unique()

    # get the 10 closest matches to our input string
    matches = fuzzywuzzy.process.extract(string_to_match, strings, limit=10,
                                         scorer=fuzzywuzzy.fuzz.token_sort_ratio)
    
    # only get matches with ratio > 90
    close_matches = [matches[0] for matches in matches if matches[1] >= min_ratio]

    # get the rows of all the close matches in our dataframe
    rows_with_matches = df[column].isin(close_matches)

    # replace all rows with close matches with input matches
    df.loc[rows_with_matches, column] = string_to_match

    # response
    print("Matches Replaced Successfully!")

# %%
# use the function we just wrote to replace close matches to "south korea" with "south korea"
replace_matches_in_columns(df=professors, column="Country", string_to_match="south korea")
# Out:
# Matches Replaced Successfully!

# %%
countries = professors["Country"].unique()

countries.sort()
countries
# Out:
# array(['australia', 'austria', 'canada', 'china', 'finland', 'france',
#        'germany', 'greece', 'hongkong', 'ireland', 'italy', 'japan',
#        'macau', 'malaysia', 'mauritius', 'netherland', 'new zealand',
#        'norway', 'pakistan', 'portugal', 'russian federation',
#        'saudi arabia', 'scotland', 'singapore', 'south korea', 'spain',
#        'sweden', 'thailand', 'turkey', 'uk', 'urbana', 'usa', 'usofa'],
#       dtype=object)

# %%
professors.columns
# Out:
# Index(['Unnamed: 0', 'S#', 'Teacher Name', 'University Currently Teaching',
#        'Department', 'Province University Located', 'Designation',
#        'Terminal Degree', 'Graduated from', 'Country', 'Year',
#        'Area of Specialization/Research Interests', 'Other Information'],
#       dtype='object')
