# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings

# %%
sns.set_style("whitegrid")
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)
warnings.filterwarnings('ignore')


df = pd.read_csv("../datasets/movielens1m.csv")
df = df.astype(np.uint8, errors='ignore') # reduce memory footprint
print("Number of Unique Zipcodes: {}".format(df["Zipcode"].nunique()))
# Out:
# Number of Unique Zipcodes: 3439

# %%
X = df.copy()
y = X.pop('Rating')

X_encode = X.sample(frac=0.25)
y_encode = y[X_encode.index]
X_pretrain = X.drop(X_encode.index)
y_train = y[X_pretrain.index]

# %%
from category_encoders import MEstimateEncoder

# Create the encoder instance. Choose m to control noise.
encoder = MEstimateEncoder(cols=["Zipcode"], m=5.0)

# Fit the encoder on the encoding split.
encoder.fit(X_encode, y_encode)

# Encode the Zipcode column to create the final training data
X_train = encoder.transform(X_pretrain)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 7
#       4 encoder = MEstimateEncoder(cols=["Zipcode"], m=5.0)
#       6 # Fit the encoder on the encoding split.
# ----> 7 encoder.fit(X_encode, y_encode)
#       9 # Encode the Zipcode column to create the final training data
#      10 X_train = encoder.transform(X_pretrain)
#
# File ~/Work/Data Science/Learning/kaggle-ml/venv/lib/python3.12/site-packages/category_encoders/utils.py:299, in BaseEncoder.fit(self, X, y, **kwargs)
#     280 """Fits the encoder according to X and y.
#     281
#     282 Parameters
#    (...)
#     296
#     297 """
#     298 X, y = convert_inputs(X, y)
# --> 299 self._check_fit_inputs(X, y)
#     300 self.feature_names_in_ = X.columns.tolist()
#     301 self.n_features_in_ = len(self.feature_names_in_)
#
# File ~/Work/Data Science/Learning/kaggle-ml/venv/lib/python3.12/site-packages/category_encoders/utils.py:336, in BaseEncoder._check_fit_inputs(self, X, y)
#     335 def _check_fit_inputs(self, X, y):
# --> 336     if self._get_tags().get('supervised_encoder'):
#     337         if y is None:
#     338             raise ValueError('Supervised encoders need a target for the fitting. The target cannot be None')
#
# File ~/Work/Data Science/Learning/kaggle-ml/venv/lib/python3.12/site-packages/sklearn/base.py:417, in BaseEstimator._get_tags(self)
#     409 from sklearn.utils._tags import _to_old_tags, get_tags
#     411 warnings.warn(
#     412     "The `_get_tags` method is deprecated in 1.6 and will be removed in "
#     413     "1.7. Please implement the `__sklearn_tags__` method.",
#     414     category=FutureWarning,
#     415 )
# --> 417 return _to_old_tags(get_tags(self))
#
# File ~/Work/Data Science/Learning/kaggle-ml/venv/lib/python3.12/site-packages/sklearn/utils/_tags.py:405, in get_tags(estimator)
#     403 for klass in reversed(type(estimator).mro()):
#     404     if "__sklearn_tags__" in vars(klass):
# --> 405         sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     406         class_order.append(klass)
#     407     elif "_more_tags" in vars(klass):
#
# File ~/Work/Data Science/Learning/kaggle-ml/venv/lib/python3.12/site-packages/sklearn/base.py:859, in TransformerMixin.__sklearn_tags__(self)
#     858 def __sklearn_tags__(self):
# --> 859     tags = super().__sklearn_tags__()
#     860     tags.transformer_tags = TransformerTags()
#     861     return tags
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'

# %%
plt.figure(dpi=90)
ax = sns.distplot(y, kde=False, norm_hist=True)
ax = sns.kdeplot(X_train.Zipcode, color='r', ax=ax)
ax.set_xlabel("Rating")
ax.legend(labels=['Zipcode', 'Rating']);
